# %%
from PIL import Image
from numpy import*
from sklearn import svm
import numpy

clf = svm.SVC(gamma=0.001, C=100.)

cat1=list(Image.open('cat.jpg').getdata())

cat1
# Out:
# [(242, 237, 255),
#  (237, 232, 255),
#  (225, 222, 243),
#  (211, 209, 230),
#  (195, 194, 212),
#  (168, 169, 187),
#  (133, 135, 150),
#  (104, 108, 120),
#  (83, 87, 99),
#  (81, 83, 95),
#  (75, 78, 87),
#  (70, 70, 80),
#  (62, 62, 70),
#  (55, 54, 62),
#  (50, 47, 54),
#  (47, 44, 51),
#  (52, 45, 52),
#  (53, 46, 53),
#  (54, 47, 54),
#  (53, 48, 54),
#  (51, 49, 54),
#  (52, 50, 53),
#  (54, 52, 55),
#  (56, 54, 55),
#  (64, 62, 63),
#  (73, 69, 68),
#  (82, 78, 77),
#  (90, 85, 82),
#  (98, 90, 88),
#  (106, 96, 95),
#  (115, 105, 104),
#  (123, 111, 111),
#  (131, 120, 116),
#  (133, 122, 118),
#  (138, 125, 119),
#  (139, 126, 120),
#  (138, 125, 119),
#  (135, 122, 114),
#  (134, 121, 113),
#  (131, 120, 114),
#  (130, 119, 113),
#  (124, 115, 110),
#  (119, 111, 108),
#  (116, 112, 109),
#  (114, 113, 111),
#  (113, 113, 113),
#  (115, 117, 116),
#  (119, 120, 122),
#  (124, 125, 127),
#  (130, 131, 133),
#  (139, 140, 142),
#  (148, 149, 151),
#  (155, 156, 158),
# ...

# %%
# from matplotlib import pyplot as plt
# plt.imshow(temp)
# plt.show()
